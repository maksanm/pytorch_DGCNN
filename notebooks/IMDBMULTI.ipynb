# %% [markdown]
# # IMDBMULTI dataset

# %%
import os
os.chdir("..")

from ResultParser import ResultParser

# %%
results_path = 'outputs/IMDBMULTI_output.txt'

# %% [markdown]
# ## Loading results and displaying metrics

# %%
results = ResultParser(results_path)
results.display_basic_metrics()
# Out:
# Result for dataset IMDBMULTI calculated with batch size 64
#
# Last epoch accuracy for every fold on train set: [0.5186, 0.4933, 0.52083, 0.51116, 0.52009, 0.52455, 0.5253, 0.51488, 0.52307, 0.51488]
# Last epoch accuracy for every fold on test set: [0.44667, 0.56, 0.46, 0.42667, 0.47333, 0.48, 0.46, 0.53333, 0.48, 0.48]
#
# Average last epoch accuracy on train set: 0.516666
# Last epoch accuracy std on train set: 0.008906083538795264
# Average last epoch accuracy on test set: 0.4800000000000001
# Last epoch accuracy std on test set: 0.03747473228723589

# %% [markdown]
# ## Plotting training history

# %% [markdown]
# ### accuracy

# %%
results.plot_metric('train', 'accuracy')
results.plot_metric('test', 'accuracy')
results.plot_averaged_metric("accuracy")

# %% [markdown]
# ### loss

# %%
results.plot_metric('train', 'loss')
results.plot_metric('test', 'loss')
results.plot_averaged_metric("loss")
