# %% [markdown]
# # IMDBMULTI dataset

# %%
import os
os.chdir("..")

from ResultParser import ResultParser

# %%
results_path = 'outputs/IMDBMULTI_output.txt'

# %% [markdown]
# ## Loading results and displaying metrics

# %%
results = ResultParser(results_path)
results.display_basic_metrics()
# Out:
# Result for dataset IMDBMULTI calculated with batch size 32
#
# Last epoch accuracy for every fold on train set: [0.52753, 0.5119, 0.53199, 0.52381, 0.53348, 0.54464, 0.52827, 0.52976]
# Last epoch accuracy for every fold on test set: [0.48, 0.58, 0.47333, 0.48, 0.45333, 0.50667, 0.48, 0.48667]
#
# Average last epoch accuracy on train set: 0.5289225
# Last epoch accuracy std on train set: 0.008632710683788717
# Average last epoch accuracy on test set: 0.49249999999999994
# Last epoch accuracy std on test set: 0.035814723927457534

# %% [markdown]
# ## Plotting training history

# %% [markdown]
# ### accuracy

# %%
results.plot_metric('train', 'accuracy')
results.plot_metric('test', 'accuracy')
results.plot_averaged_metric("accuracy")

# %% [markdown]
# ### loss

# %%
results.plot_metric('train', 'loss')
results.plot_metric('test', 'loss')
results.plot_averaged_metric("loss")
