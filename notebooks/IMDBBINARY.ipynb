# %% [markdown]
# # IMDBBINARY dataset

# %%
import os
os.chdir("..")

from ResultParser import ResultParser

# %%
results_path = 'outputs/IMDBBINARY_output.txt'

# %% [markdown]
# ## Loading results and displaying metrics

# %%
results = ResultParser(results_path)
results.display_basic_metrics()
# Out:
# Result for dataset IMDBBINARY calculated with batch size 32
#
# Last epoch accuracy for every fold on train set: [0.73326, 0.73103, 0.72879, 0.72545, 0.72991, 0.73438, 0.73549, 0.73103, 0.73884, 0.72433]
# Last epoch accuracy for every fold on test set: [0.69, 0.56, 0.72, 0.75, 0.67, 0.65, 0.7, 0.81, 0.65, 0.67]
#
# Average last epoch accuracy on train set: 0.731251
# Last epoch accuracy std on train set: 0.004229575510615692
# Average last epoch accuracy on test set: 0.687
# Last epoch accuracy std on test set: 0.06309516621738942

# %% [markdown]
# ## Plotting training history

# %% [markdown]
# ### accuracy

# %%
results.plot_metric('train', 'accuracy')
results.plot_metric('test', 'accuracy')
results.plot_averaged_metric("accuracy")

# %% [markdown]
# ### loss

# %%
results.plot_metric('train', 'loss')
results.plot_metric('test', 'loss')
results.plot_averaged_metric("loss")
