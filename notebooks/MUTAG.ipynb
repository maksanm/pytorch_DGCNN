# %% [markdown]
# # MUTAG dataset

# %%
import os
os.chdir("..")

from ResultParser import ResultParser

# %%
results_path = 'outputs/MUTAG_output.txt'

# %% [markdown]
# ## Loading results and displaying metrics

# %%
results = ResultParser(results_path)
results.display_basic_metrics()
# Out:
# Result for dataset MUTAG calculated with batch size 16
#
# Last epoch accuracy for every fold on train set: [0.93125, 0.86875, 0.8875, 0.89375, 0.89375, 0.8875, 0.8875, 0.91875, 0.9125, 0.8875]
# Last epoch accuracy for every fold on test set: [0.77778, 0.88889, 0.94444, 0.83333, 0.83333, 0.77778, 0.83333, 0.72222, 0.94444, 0.88889]
#
# Average last epoch accuracy on train set: 0.8968749999999999
# Last epoch accuracy std on train set: 0.017511157157652373
# Average last epoch accuracy on test set: 0.844443
# Last epoch accuracy std on test set: 0.06938785254639314

# %% [markdown]
# ## Plotting training history

# %% [markdown]
# ### accuracy

# %%
results.plot_metric('train', 'accuracy')
results.plot_metric('test', 'accuracy')
results.plot_averaged_metric("accuracy")

# %% [markdown]
# ### loss

# %%
results.plot_metric('train', 'loss')
results.plot_metric('test', 'loss')
results.plot_averaged_metric("loss")
