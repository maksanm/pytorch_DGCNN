# %% [markdown]
# # MUTAG dataset

# %%
import os
os.chdir("..")

from ResultParser import ResultParser

# %%
results_path = 'outputs/MUTAG_bsz100.txt'

# %% [markdown]
# ## Loading results and displaying metrics

# %%
results = ResultParser(results_path)
results.display_basic_metrics()
# Out:
# Result for dataset MUTAG calculated with batch size 100
#
# Last epoch accuracy for every fold on train set: [0.88, 0.84, 0.84, 0.84, 0.83, 0.86, 0.85, 0.88, 0.83, 0.87]
# Last epoch accuracy for every fold on test set: [0.72222, 0.94444, 0.88889, 0.83333, 0.83333, 0.83333, 0.83333, 0.83333, 0.77778, 0.94444]
#
# Best epoch accuracy for every fold on train set: [0.91, 0.9, 0.9, 0.89, 0.89, 0.9, 0.9, 0.91, 0.92, 0.9]
# Best epoch accuracy for every fold on test set: [0.72222, 0.94444, 0.88889, 0.83333, 0.88889, 0.83333, 0.83333, 0.88889, 0.77778, 0.94444]
#
# Average last epoch accuracy on train set: 0.852
# Average last epoch accuracy on test set: 0.8444419999999999
#
# Average best epoch accuracy on train set: 0.9020000000000001
# Average best epoch accuracy on test set: 0.855554

# %% [markdown]
# ## Plotting training history

# %% [markdown]
# ### accuracy

# %%
results.plot_metric('train', 'accuracy')
results.plot_metric('test', 'accuracy')
results.plot_averaged_metric("accuracy")

# %% [markdown]
# ### loss

# %%
results.plot_metric('train', 'loss')
results.plot_metric('test', 'loss')
results.plot_averaged_metric("loss")
