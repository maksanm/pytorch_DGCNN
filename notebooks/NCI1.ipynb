# %% [markdown]
# # NCI1 dataset

# %%
import os
os.chdir("..")

from ResultParser import ResultParser

# %%
results_path = 'outputs/NCI1_output.txt'

# %% [markdown]
# ## Loading results and displaying metrics

# %%
results = ResultParser(results_path)
results.display_basic_metrics()
# Out:
# Result for dataset NCI1 calculated with batch size 100
#
# Last epoch accuracy for every fold on train set: [0.76639, 0.74083, 0.75722, 0.76028, 0.755, 0.75778, 0.73806, 0.7425, 0.74889, 0.74833]
# Last epoch accuracy for every fold on test set: [0.7129, 0.73479, 0.70803, 0.71533, 0.73966, 0.72263, 0.73236, 0.66667, 0.75669, 0.74453]
#
# Best epoch accuracy for every fold on train set: [0.76917, 0.75278, 0.76556, 0.76778, 0.76444, 0.77028, 0.755, 0.75278, 0.75778, 0.75528]
# Best epoch accuracy for every fold on test set: [0.72506, 0.74939, 0.71533, 0.73723, 0.75182, 0.72506, 0.75182, 0.70316, 0.75912, 0.76886]
#
# Average last epoch accuracy on train set: 0.7515280000000001
# Average last epoch accuracy on test set: 0.7233590000000001
#
# Average best epoch accuracy on train set: 0.761085
# Average best epoch accuracy on test set: 0.738685

# %% [markdown]
# ## Plotting training history

# %% [markdown]
# ### accuracy

# %%
results.plot_metric('train', 'accuracy')
results.plot_metric('test', 'accuracy')
results.plot_averaged_metric("accuracy")

# %% [markdown]
# ### loss

# %%
results.plot_metric('train', 'loss')
results.plot_metric('test', 'loss')
results.plot_averaged_metric("loss")
