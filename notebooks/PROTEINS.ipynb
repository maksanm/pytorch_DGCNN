# %% [markdown]
# # PROTEINS dataset

# %%
import os
os.chdir("..")

from ResultParser import ResultParser

# %%
results_path = 'outputs/PROTEINS_output.txt'

# %% [markdown]
# ## Loading results and displaying metrics

# %%
results = ResultParser(results_path)
results.display_basic_metrics()
# Out:
# Result for dataset PROTEINS calculated with batch size 50
#
# Last epoch accuracy for every fold on train set: [0.737, 0.733, 0.741, 0.731, 0.732, 0.735, 0.725, 0.721, 0.731, 0.73]
# Last epoch accuracy for every fold on test set: [0.71171, 0.74775, 0.68468, 0.72072, 0.73874, 0.64865, 0.79279, 0.81081, 0.71171, 0.72072]
#
# Best epoch accuracy for every fold on train set: [0.746, 0.742, 0.75, 0.742, 0.743, 0.75, 0.732, 0.737, 0.745, 0.746]
# Best epoch accuracy for every fold on test set: [0.73874, 0.78378, 0.68468, 0.76577, 0.75676, 0.69369, 0.83784, 0.81081, 0.71171, 0.75676]
#
# Average last epoch accuracy on train set: 0.7316
# Average last epoch accuracy on test set: 0.728828
#
# Average best epoch accuracy on train set: 0.7433
# Average best epoch accuracy on test set: 0.754054

# %% [markdown]
# ## Plotting training history

# %% [markdown]
# ### accuracy

# %%
results.plot_metric('train', 'accuracy')
results.plot_metric('test', 'accuracy')
results.plot_averaged_metric("accuracy")

# %% [markdown]
# ### loss

# %%
results.plot_metric('train', 'loss')
results.plot_metric('test', 'loss')
results.plot_averaged_metric("loss")
