# %% [markdown]
# # PROTEINS dataset

# %%
import os
os.chdir("..")

from ResultParser import ResultParser

# %%
results_path = 'outputs/PROTEINS_output.txt'

# %% [markdown]
# ## Loading results and displaying metrics

# %%
results = ResultParser(results_path)
results.display_basic_metrics()
# Out:
# Result for dataset PROTEINS calculated with batch size 32
#
# Last epoch accuracy for every fold on train set: [0.74294, 0.72782, 0.73488, 0.72984, 0.72883, 0.74194, 0.72177, 0.71774, 0.72581, 0.7248]
# Last epoch accuracy for every fold on test set: [0.71171, 0.75676, 0.68468, 0.71171, 0.73874, 0.64865, 0.81081, 0.81081, 0.72072, 0.72072]
#
# Average last epoch accuracy on train set: 0.7296370000000001
# Last epoch accuracy std on train set: 0.0077542724352449785
# Average last epoch accuracy on test set: 0.731531
# Last epoch accuracy std on test set: 0.048314146675689125

# %% [markdown]
# ## Plotting training history

# %% [markdown]
# ### accuracy

# %%
results.plot_metric('train', 'accuracy')
results.plot_metric('test', 'accuracy')
results.plot_averaged_metric("accuracy")

# %% [markdown]
# ### loss

# %%
results.plot_metric('train', 'loss')
results.plot_metric('test', 'loss')
results.plot_averaged_metric("loss")
